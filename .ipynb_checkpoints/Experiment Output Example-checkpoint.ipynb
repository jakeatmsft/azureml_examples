# %%
import logging

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

import azureml.core
from azureml.core.run import Run
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
import azureml.dataprep as dprep
from azureml.core.dataset import Dataset

import pandas as pd

ws = Workspace.from_config()

# %%
output = {}
output['Subscription ID'] = ws.subscription_id
output['Workspace Name'] = ws.name
output['Resource Group'] = ws.resource_group
output['Location'] = ws.location

pd.set_option('display.max_colwidth', -1)
outputDf = pd.DataFrame(data = output, index = [''])
outputDf.T
# Out:
#
# Subscription ID  7fd76d0f-84f2-498b-a997-e0d059af5ce1
# Workspace Name   wu2modtimesmlsw
# Resource Group   wu2modtimerg
# Location         westus2

# %%
pl = pd.DataFrame()
exp = Experiment(ws, 'automl-exp-name')
algo=''
pp=''
fmwk=''

list_runs = exp.get_runs()
for run in list_runs:
    run_details = run.get_details()
    output = run.get_metrics(recursive=True)
    children = run.get_children()
    for cr in children:
        algo = cr.get_details()['properties']['run_algorithm']
        pp = cr.get_details()['properties']['run_algorithm']
        fmwk = cr.get_details()['properties']['run_algorithm']
        output = cr.get_metrics()
        df  = pd.DataFrame(output, index=[0])
        df['algo'] = algo
        df['preprocessor'] = pp
        df['framework'] = fmwk
        pl = pd.concat([pl, df])

display(pl)
# Out:
# C:\Users\jakew\Anaconda3\envs\azure\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#    AUC_macro  AUC_micro  AUC_weighted  accuracy  \
# 0 NaN        NaN        NaN           NaN
# 0  0.986199   0.986199   0.986199      0.966397
# 0 NaN        NaN        NaN           NaN
# 0  0.971894   0.971894   0.971894      0.930218
# 0  0.945681   0.945681   0.945681      0.894331
# 0  0.986640   0.986640   0.986640      0.971139
# 0  0.983941   0.983941   0.983941      0.951525
# 0  0.975265   0.975265   0.975265      0.939145
# 0  0.966185   0.966185   0.966185      0.914409
# 0 NaN        NaN        NaN           NaN
#
#                                                                                      accuracy_table  \
# 0  NaN
# 0  aml://artifactId/ExperimentRun/dcid.AutoML_986ec177-7118-42b4-b34d-3b8d0ac0ed1b_8/accuracy_table
# 0  NaN
# 0  aml://artifactId/ExperimentRun/dcid.AutoML_986ec177-7118-42b4-b34d-3b8d0ac0ed1b_6/accuracy_table
# 0  aml://artifactId/ExperimentRun/dcid.AutoML_986ec177-7118-42b4-b34d-3b8d0ac0ed1b_5/accuracy_table
# 0  aml://artifactId/ExperimentRun/dcid.AutoML_986ec177-7118-42b4-b34d-3b8d0ac0ed1b_4/accuracy_table
# 0  aml://artifactId/ExperimentRun/dcid.AutoML_986ec177-7118-42b4-b34d-3b8d0ac0ed1b_3/accuracy_table
# 0  aml://artifactId/ExperimentRun/dcid.AutoML_986ec177-7118-42b4-b34d-3b8d0ac0ed1b_2/accuracy_table
# 0  aml://artifactId/ExperimentRun/dcid.AutoML_986ec177-7118-42b4-b34d-3b8d0ac0ed1b_0/accuracy_table
# 0  NaN
#
#                  algo  average_precision_score_macro  \
# 0  Ensemble           NaN
# 0  LightGBM            0.976127
# 0  LightGBM           NaN
# 0  LightGBM            0.944175
# 0  LightGBM            0.886662
# 0  LogisticRegression  0.977846
# 0  LightGBM            0.967798
# 0  LightGBM            0.952569
# 0  LightGBM            0.931362
# 0  LightGBM           NaN
#
#    average_precision_score_micro  average_precision_score_weighted  \
# 0 NaN                            NaN
# 0  0.976127                       0.976127
# 0 NaN                            NaN
# 0  0.944175                       0.944175
# 0  0.886662                       0.886662
# 0  0.977846                       0.977846
# 0  0.967798                       0.967798
# 0  0.952569                       0.952569
# 0  0.931362                       0.931362
# 0 NaN                            NaN
#
#    balanced_accuracy  ...  log_loss  norm_macro_recall  precision_score_macro  \
# 0 NaN                 ... NaN       NaN                NaN
# 0  0.921377           ...  0.185864  0.842754           0.978054
# 0 NaN                 ... NaN       NaN                NaN
# 0  0.834316           ...  0.220194  0.668632           0.959307
# 0  0.749115           ...  0.285487  0.498230           0.940724
# 0  0.960883           ...  0.160985  0.921766           0.953171
# 0  0.884970           ...  0.165845  0.769939           0.970929
# 0  0.855808           ...  0.199759  0.711615           0.963693
# 0  0.796755           ...  0.250226  0.593509           0.950996
# 0 NaN                 ... NaN       NaN                NaN
#
#    precision_score_micro precision_score_weighted        preprocessor  \
# 0 NaN                    NaN                       Ensemble
# 0  0.966397               0.967566                 LightGBM
# 0 NaN                    NaN                       LightGBM
# 0  0.930218               0.935893                 LightGBM
# 0  0.894331               0.906728                 LightGBM
# 0  0.971139               0.971457                 LogisticRegression
# 0  0.951525               0.954307                 LightGBM
# 0  0.939145               0.943405                 LightGBM
# 0  0.914409               0.922755                 LightGBM
# 0 NaN                    NaN                       LightGBM
#
#    recall_score_macro  recall_score_micro  recall_score_weighted  \
# 0 NaN                 NaN                 NaN
# 0  0.921377            0.966397            0.966397
# 0 NaN                 NaN                 NaN
# 0  0.834316            0.930218            0.930218
# 0  0.749115            0.894331            0.894331
# 0  0.960883            0.971139            0.971139
# 0  0.884970            0.951525            0.951525
# 0  0.855808            0.939145            0.939145
# 0  0.796755            0.914409            0.914409
# 0 NaN                 NaN                 NaN
#
#    weighted_accuracy
# 0 NaN
# 0  0.988811
# 0 NaN
# 0  0.977966
# 0  0.966628
# 0  0.976245
# 0  0.984662
# 0  0.980641
# 0  0.972985
# 0 NaN
#
# [10 rows x 25 columns]
